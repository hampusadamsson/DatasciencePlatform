# %%
import requests
import json
import urllib
import matplotlib.pyplot as plt
import numpy as np
from pandas import DataFrame as pd

# %%
ip = "127.0.0.1"
port = "5002"
query = "http://{}:{}/health".format(ip, port)
r = requests.get(query)
json.loads(r.text)
# Out:
# {'success': True}

# %%
query = "http://{}:{}/getDistinct".format(ip, port)
r = requests.get(query)
inp = json.loads(r.text)
dist = pd.from_dict(inp)
dist
# Out:
#     symbol
# 0     MSFT
# 1      SPX
# 10     AMD
# 100    CNC
# 101    CNP
# 102    CTL
# 103   CERN
# 104     CF
# 105   SCHW
# 106   CHTR
# 107    CVX
# 108    CMG
# 109     CB
# 11     AAP
# 110    CHD
# 111     CI
# 112    XEC
# 113   CINF
# 114   CTAS
# 115   CSCO
# 116      C
# 117    CFG
# 118   CTXS
# 119    CLX
# 12     AES
# 120    CME
# 121    CMS
# 122     KO
# 123   CTSH
# 124     CL
# ..     ...
# 72   BRK.B
# 73     BBY
# 74    BIIB
# 75     BLK
# 76     HRB
# 77      BA
# 78    BKNG
# 79     BWA
# 8     ATVI
# 80     BXP
# 81     BSX
# 82     BHF
# 83     BMY
# 84    AVGO
# 85      BR
# 86    CHRW
# 87     COG
# 88    CDNS
# 89     CPB
# 9     ADBE
# 90     COF
# 91     CAH
# 92     KMX
# 93     CCL
# 94     CAT
# 95    CBOE
# 96    CBRE
# 97     CBS
# 98      CE
# 99    CELG
#
# [501 rows x 1 columns]

# %%
query = "http://{}:{}/getStock/MSFT".format(ip, port)
r = requests.get(query)
inp = json.loads(r.text)
df = pd.from_dict(inp)
df = df.sort_values(by='date')
df
# Out:
#       adjusted_close   close        date  dividend_amount     high  \
# 5415         10.6408  131.13  1998-01-02              0.0  131.500
# 5414         10.5799  130.38  1998-01-05              0.0  133.630
# 5413         10.6408  131.13  1998-01-06              0.0  133.000
# 5412         10.5134  129.56  1998-01-07              0.0  131.190
# 5411         10.5897  130.50  1998-01-08              0.0  132.130
# 5410         10.3057  127.00  1998-01-09              0.0  131.500
# 5409         10.5085  129.50  1998-01-12              0.0  130.000
# 5408         10.7220  132.13  1998-01-13              0.0  132.250
# 5407         10.6408  131.13  1998-01-14              0.0  132.500
# 5406         10.7366  132.31  1998-01-15              0.0  133.000
# 5405         10.9751  135.25  1998-01-16              0.0  135.380
# 5404         11.1829  137.81  1998-01-20              0.0  138.000
# 5403         11.1171  137.00  1998-01-21              0.0  138.440
# 5402         11.2494  138.63  1998-01-22              0.0  139.880
# 5401         11.2186  138.25  1998-01-23              0.0  139.440
# 5400         11.5026  141.75  1998-01-26              0.0  141.880
# 5399         11.7817  145.19  1998-01-27              0.0  145.880
# 5398         12.0909  149.00  1998-01-28              0.0  149.500
# 5397         12.0300  148.25  1998-01-29              0.0  150.130
# 5396         12.1063  149.19  1998-01-30              0.0  150.000
# 5395         12.5680  154.88  1998-02-02              0.0  155.130
# 5394         12.6492  155.88  1998-02-03              0.0  156.130
# 5393         12.7247  156.81  1998-02-04              0.0  158.000
# 5392         12.6135  155.44  1998-02-05              0.0  158.750
# 5391         12.8318  158.13  1998-02-06              0.0  158.250
# 5390         12.7555  157.19  1998-02-09              0.0  158.880
# 2     MSFT2019-07-10  137.0200  137.13                1.0   MSFT  24204362
# 1     MSFT2019-07-11  137.8700  138.20                1.0   MSFT  22327942
# 0     MSFT2019-07-12  138.0099  138.85                1.0   MSFT  18884297
#
# [5416 rows x 11 columns]

# %%
# Target value - i days into the future
i = 2
target = (df["adjusted_close"].shift(-i) - df["adjusted_close"]) / df["adjusted_close"]

# %%
# from sklearn.base import BaseEstimator, ClassifierMixin

# class stockTransformer(BaseEstimator, ClassifierMixin):
#     def __init__(self):
#         pass

#     def fit(self, X, y=None):
#         return self

#     def _meaning(self, x):
#         return(True)

#     def transform(self, tmp, y=None):
#         #Vi tittar tillbaka {i} dagar
#         for j in [1,2,3,5,7,10]: #range(1, 10):
#             for c in ["adjusted_close", "high", "low", "open", "volume"]: #"close", 
#                 tmp["hist_{}_{}".format(c,j)] = (tmp[c].shift(j) - tmp[c]) / tmp[c]

#         # Date -> month / day
#         tmp["month"] = tmp["date"].apply(lambda x : x.split("-")[1])
#         tmp["day"] = tmp["date"].apply(lambda x : x.split("-")[2])

#         tmp = tmp.drop(["adjusted_close", "close", "date", "dividend_amount", "high", "id", "low", "open", "split_coefficient", "symbol", "volume"], axis=1)
#         return tmp.fillna(-1)  # TODO - ta bort NaN från både X/Y
        
#     def predict(self, X, y=None):
#         return(X)

#     def score(self, X, y=None):
#         return(sum(self.predict(X)))

# %%
from pandas import Timestamp
t = Timestamp("1999-02-02")
str(t).split("-")
# st = stockTransformer()
# tmp = st.transform(df)[:2]
# Out:
# ['1999', '02', '02 00:00:00']

# %%
import pandas
# df.date = df.date.astype(str)
# df.info()

# df.date.map(lambda x: x.split("-"))
# df.date.astype()
tmp = df.to_json()
j = pandas.read_json(tmp)
j.date = j.date.astype(str)
j.head().date.map(lambda x: str(x).split("-"))
# Out:
# 0       [2019, 07, 12]
# 1       [2019, 07, 11]
# 10      [2019, 06, 27]
# 100     [2019, 02, 19]
# 1000    [2015, 07, 22]
# Name: date, dtype: object

# %%
import requests

url = "http://127.0.0.1:5002/invocations"
data = df[:2]
headers = {
    'Content-Type': 'application/json; format=pandas-split',
}

response = requests.post(url, headers=headers, data=data.to_json(orient='split'))
response.text
# data.to_json()
# data
# Out:
# '[-0.010185381292896664, -0.0018984001592138808]'

# %%
#
# Wine test
#

import pandas as pd 

wine_path = "/home/hades/program/python/jupyter/stock19/wine-quality.csv"
data = pd.read_csv(wine_path)

url = "http://127.0.0.1:5003/invocations"
data = data[:2] #.to_json()

headers = {
    'Content-Type': 'application/json; format=pandas-split',
}


# d2 = '{"columns":["alcohol", "chlorides", "citric acid", "density", "fixed acidity", "free sulfur dioxide", "pH", "residual sugar", "sulphates", "total sulfur dioxide", "volatile acidity"],"data":[[12.8, 0.029, 0.48, 0.98, 6.2, 29, 3.33, 1.2, 0.39, 75, 0.66]]}'

response = requests.post('http://127.0.0.1:5003/invocations', headers=headers, data=data.drop(columns=['quality']).to_json(orient='split'))
response.text

# print(d)
# print()
# print(str(d2))
# data.to_json()
# data.drop(columns=['quality']).to_json()
# Out:
# '[5.655099099229193, 5.630318463109261]'
